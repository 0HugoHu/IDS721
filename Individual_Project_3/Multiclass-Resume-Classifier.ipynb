# %% [markdown]
# ## Importing Modules

# %%
# !pip install nltk
# !pip install gensim
# !pip install wordcloud
# !pip install pandas
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/hugo-u/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/hugo-u/.local/lib/python3.10/site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: tqdm in /home/hugo-u/.local/lib/python3.10/site-packages (from nltk) (4.61.1)
# Requirement already satisfied: joblib in /home/hugo-u/.local/lib/python3.10/site-packages (from nltk) (1.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /home/hugo-u/.local/lib/python3.10/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/hugo-u/.local/lib/python3.10/site-packages (from gensim) (1.22.3)
# Requirement already satisfied: scipy>=1.7.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from gensim) (1.8.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from gensim) (6.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in /home/hugo-u/.local/lib/python3.10/site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /home/hugo-u/.local/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: pillow in /home/hugo-u/.local/lib/python3.10/site-packages (from wordcloud) (9.1.0)
# Requirement already satisfied: numpy>=1.6.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from wordcloud) (1.22.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/hugo-u/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/hugo-u/.local/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in /home/hugo-u/.local/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/hugo-u/.local/lib/python3.10/site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.25->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/hugo-u/.local/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/hugo-u/.local/lib/python3.10/site-packages (from scikit-learn) (1.22.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/hugo-u/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/hugo-u/.local/lib/python3.10/site-packages (from scikit-learn) (1.8.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/hugo-u/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import gensim
import re
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.metrics import classification_report, confusion_matrix
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/hugo-u/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/hugo-u/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('Resume.csv')
df.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
# drop not using columns
df.drop(columns = ['ID', 'Resume_html'], inplace = True)
df
# Out:
#                                              Resume_str  Category
# 0              HR ADMINISTRATOR/MARKETING ASSOCIATE\...        HR
# 1              HR SPECIALIST, US HR OPERATIONS      ...        HR
# 2              HR DIRECTOR       Summary      Over 2...        HR
# 3              HR SPECIALIST       Summary    Dedica...        HR
# 4              HR MANAGER         Skill Highlights  ...        HR
# ...                                                 ...       ...
# 2479           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...  AVIATION
# 2480           GOVERNMENT RELATIONS, COMMUNICATIONS ...  AVIATION
# 2481           GEEK SQUAD AGENT         Professional...  AVIATION
# 2482           PROGRAM DIRECTOR / OFFICE MANAGER    ...  AVIATION
# 2483           STOREKEEPER II       Professional Sum...  AVIATION
#
# [2484 rows x 2 columns]

# %%
STEMMER = nltk.stem.porter.PorterStemmer()
def preprocess(txt):
    # convert all characters in the string to lower case
    txt = txt.lower()
    # remove non-english characters, punctuation and numbers
    txt = re.sub('[^a-zA-Z]', ' ', txt)
    # tokenize word
    txt = nltk.tokenize.word_tokenize(txt)
    # remove stop words
    txt = [w for w in txt if not w in nltk.corpus.stopwords.words('english')]
    # stemming
    txt = [STEMMER.stem(w) for w in txt]

    return ' '.join(txt)

df['Resume'] = df['Resume_str'].apply(lambda w: preprocess(w))
# drop original text column
df.pop('Resume_str')
df
# Out:
#       Category                                             Resume
# 0           HR  hr administr market associ hr administr summar...
# 1           HR  hr specialist us hr oper summari versatil medi...
# 2           HR  hr director summari year experi recruit plu ye...
# 3           HR  hr specialist summari dedic driven dynam year ...
# 4           HR  hr manag skill highlight hr skill hr depart st...
# ...        ...                                                ...
# 2479  AVIATION  rank sgt e non commiss offic charg brigad mail...
# 2480  AVIATION  govern relat commun organiz develop director p...
# 2481  AVIATION  geek squad agent profession profil support spe...
# 2482  AVIATION  program director offic manag summari highli pe...
# 2483  AVIATION  storekeep ii profession summari purpos documen...
#
# [2484 rows x 2 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  2484 non-null   object
#  1   Resume    2484 non-null   object
# dtypes: object(2)
# memory usage: 38.9+ KB

# %%
df['Category'].value_counts()
# Out:
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# FINANCE                   118
# ADVOCATE                  118
# ACCOUNTANT                118
# ENGINEERING               118
# CHEF                      118
# AVIATION                  117
# FITNESS                   117
# SALES                     116
# BANKING                   115
# HEALTHCARE                115
# CONSULTANT                115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.show()

# %%
from matplotlib.gridspec import GridSpec
count=df['Category'].value_counts()
label=df['Category'].value_counts().keys()

plt.figure(1, figsize=(25,25))
grid=GridSpec(2,2)

cmap=plt.get_cmap('coolwarm')

color=[cmap(i) for i in np.linspace(0, 1, 5)]
plt.subplot(grid[0,1], aspect=1, title='Distribution')

pie=plt.pie(count, labels=label, autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
#defining stopwords
stop_words = stopwords.words('english')
#function which stop words and the words less than 2 characters
def remove_stop_words (text):
  result = []
  for token in gensim.utils.simple_preprocess(text):
    if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
      result.append(token)

  return result

df['clean'] = df['Resume'].apply(remove_stop_words).astype(str)
df['clean'][0]
# Out:
# "['administr', 'market', 'associ', 'administr', 'summari', 'dedic', 'custom', 'servic', 'manag', 'year', 'experi', 'hospit', 'custom', 'servic', 'manag', 'respect', 'builder', 'leader', 'custom', 'focus', 'team', 'strive', 'instil', 'share', 'enthusiast', 'commit', 'custom', 'servic', 'highlight', 'focus', 'custom', 'satisfact', 'team', 'manag', 'market', 'savvi', 'conflict', 'resolut', 'techniqu', 'train', 'develop', 'skill', 'multi', 'tasker', 'client', 'relat', 'specialist', 'accomplish', 'missouri', 'supervisor', 'train', 'certif', 'certifi', 'custom', 'loyalti', 'market', 'segment', 'hilton', 'worldwid', 'gener', 'manag', 'train', 'certif', 'accomplish', 'trainer', 'cross', 'server', 'hospit', 'hilton', 'micro', 'opera', 'fidelio', 'opera', 'reserv', 'holidex', 'complet', 'cours', 'seminar', 'custom', 'servic', 'sale', 'strategi', 'inventori', 'control', 'loss', 'prevent', 'safeti', 'time', 'manag', 'leadership', 'perform', 'assess', 'experi', 'administr', 'market', 'associ', 'administr', 'current', 'compani', 'citi', 'state', 'help', 'develop', 'polici', 'direct', 'coordin', 'activ', 'employ', 'compens', 'labor', 'relat', 'benefit', 'train', 'employe', 'servic', 'prepar', 'employe', 'separ', 'notic', 'relat', 'document', 'record', 'benefit', 'plan', 'particip', 'insur', 'pension', 'plan', 'personnel', 'transact', 'hire', 'promot', 'transfer', 'perform', 'review', 'termin', 'employe', 'statist', 'govern', 'report', 'advis', 'manag', 'appropri', 'resolut', 'employe', 'relat', 'issu', 'administ', 'benefit', 'program', 'life', 'health', 'dental', 'insur', 'pension', 'plan', 'vacat', 'sick', 'leav', 'leav', 'absenc', 'employe', 'assist', 'market', 'associ', 'design', 'creat', 'market', 'collater', 'sale', 'meet', 'trade', 'compani', 'execut', 'manag', 'hous', 'advertis', 'program', 'consist', 'print', 'media', 'collater', 'piec', 'assist', 'complet', 'design', 'launch', 'compani', 'websit', 'month', 'creat', 'offici', 'compani', 'page', 'facebook', 'facilit', 'interact', 'custom', 'analyz', 'rate', 'program', 'featur', 'competitor', 'evalu', 'effect', 'market', 'strategi', 'advanc', 'medic', 'claim', 'analyst', 'compani', 'citi', 'state', 'review', 'medic', 'accuraci', 'treatment', 'test', 'hospit', 'stay', 'prior', 'sanction', 'claim', 'train', 'interpret', 'code', 'terminolog', 'commonli', 'medic', 'fulli', 'understand', 'paperwork', 'submit', 'healthcar', 'provid', 'requir', 'organiz', 'analyt', 'skill', 'comput', 'skill', 'knowledg', 'medic', 'terminolog', 'procedur', 'statist', 'standard', 'data', 'analysi', 'regard', 'medic', 'assist', 'gener', 'manag', 'compani', 'citi', 'state', 'perform', 'duti', 'includ', 'limit', 'budget', 'financi', 'manag', 'account', 'human', 'resourc', 'payrol', 'purchas', 'establish', 'maintain', 'close', 'work', 'relationship', 'depart', 'hotel', 'ensur', 'maximum', 'oper', 'product', 'moral', 'guest', 'servic', 'handl', 'daili', 'oper', 'report', 'directli', 'corpor', 'offic', 'hire', 'train', 'staff', 'overal', 'object', 'goal', 'emphasi', 'high', 'custom', 'servic', 'market', 'advertis', 'work', 'public', 'relat', 'media', 'govern', 'local', 'busi', 'chamber', 'commerc', 'execut', 'support', 'market', 'assist', 'compani', 'citi', 'state', 'provid', 'assist', 'variou', 'depart', 'head', 'execut', 'market', 'custom', 'servic', 'human', 'resourc', 'manag', 'oper', 'ensur', 'friendli', 'effici', 'transact', 'ensur', 'swift', 'resolut', 'custom', 'issu', 'preserv', 'custom', 'loyalti', 'compli', 'compani', 'polici', 'exemplifi', 'second', 'custom', 'servic', 'deliveri', 'interact', 'custom', 'potenti', 'client', 'reserv', 'offic', 'manag', 'compani', 'citi', 'state', 'owner', 'partner', 'compani', 'citi', 'state', 'price', 'integr', 'coordin', 'compani', 'citi', 'state', 'educ', 'busi', 'administr', 'jefferson', 'colleg', 'citi', 'state', 'busi', 'administr', 'market', 'advertis', 'high', 'school', 'diploma', 'colleg', 'prep', 'studi', 'saint', 'geneviev', 'senior', 'high', 'citi', 'state', 'aw ...

# %%
df
# Out:
#       Category                                             Resume  \
# 0           HR  hr administr market associ hr administr summar...
# 1           HR  hr specialist us hr oper summari versatil medi...
# 2           HR  hr director summari year experi recruit plu ye...
# 3           HR  hr specialist summari dedic driven dynam year ...
# 4           HR  hr manag skill highlight hr skill hr depart st...
# ...        ...                                                ...
# 2479  AVIATION  rank sgt e non commiss offic charg brigad mail...
# 2480  AVIATION  govern relat commun organiz develop director p...
# 2481  AVIATION  geek squad agent profession profil support spe...
# 2482  AVIATION  program director offic manag summari highli pe...
# 2483  AVIATION  storekeep ii profession summari purpos documen...
#
#                                                   clean
# 0     ['administr', 'market', 'associ', 'administr',...
# 1     ['specialist', 'oper', 'summari', 'versatil', ...
# 2     ['director', 'summari', 'year', 'experi', 'rec...
# 3     ['specialist', 'summari', 'dedic', 'driven', '...
# 4     ['manag', 'skill', 'highlight', 'skill', 'depa...
# ...                                                 ...
# 2479  ['rank', 'commiss', 'offic', 'charg', 'brigad'...
# 2480  ['govern', 'relat', 'commun', 'organiz', 'deve...
# 2481  ['geek', 'squad', 'agent', 'profession', 'prof...
# 2482  ['program', 'director', 'offic', 'manag', 'sum...
# 2483  ['storekeep', 'profession', 'summari', 'purpos...
#
# [2484 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df['clean'], df['Category'], test_size = 0.2)

from sklearn.feature_extraction.text import CountVectorizer

# vectorize text data
vectorizer = CountVectorizer()
conuntvectorizer_train = vectorizer.fit_transform(X_train).astype(float)
conuntvectorizer_test = vectorizer.transform(X_test).astype(float)

# %% [markdown]
# ## Model Training

# %%
# using grid search for find optimal values for RF classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

RFC = RandomForestClassifier(random_state=42)

param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

grid = GridSearchCV(estimator=RFC, param_grid=param_grid, cv= 5, scoring='accuracy', return_train_score=False, verbose=1)
grid_search = grid.fit(conuntvectorizer_train, Y_train)

print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'n_estimators': 500}

# %%
from sklearn.ensemble import RandomForestClassifier

RF_Model = RandomForestClassifier(random_state=42, max_features='sqrt', n_estimators= 500, max_depth=8, criterion='gini')
RF_Model.fit(conuntvectorizer_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=500, random_state=42)

# %%
prediction=RF_Model.predict(conuntvectorizer_test)
prediction
# Out:
# array(['FINANCE', 'ACCOUNTANT', 'AGRICULTURE', 'FINANCE', 'FITNESS',
#        'INFORMATION-TECHNOLOGY', 'BANKING', 'INFORMATION-TECHNOLOGY',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY', 'HR',
#        'ACCOUNTANT', 'SALES', 'INFORMATION-TECHNOLOGY', 'BANKING',
#        'BUSINESS-DEVELOPMENT', 'HR', 'SALES', 'CONSTRUCTION',
#        'CONSULTANT', 'ENGINEERING', 'AVIATION', 'INFORMATION-TECHNOLOGY',
#        'DESIGNER', 'FITNESS', 'CHEF', 'CONSTRUCTION', 'ENGINEERING',
#        'AVIATION', 'HEALTHCARE', 'TEACHER', 'CONSULTANT', 'DIGITAL-MEDIA',
#        'FITNESS', 'ACCOUNTANT', 'CONSTRUCTION', 'TEACHER', 'DESIGNER',
#        'DIGITAL-MEDIA', 'TEACHER', 'DIGITAL-MEDIA', 'CONSTRUCTION',
#        'ACCOUNTANT', 'HEALTHCARE', 'ACCOUNTANT', 'TEACHER',
#        'PUBLIC-RELATIONS', 'INFORMATION-TECHNOLOGY', 'ACCOUNTANT',
#        'HEALTHCARE', 'INFORMATION-TECHNOLOGY', 'BUSINESS-DEVELOPMENT',
#        'CONSTRUCTION', 'DESIGNER', 'FITNESS', 'SALES', 'ACCOUNTANT',
#        'APPAREL', 'CONSTRUCTION', 'SALES', 'DIGITAL-MEDIA', 'HEALTHCARE',
#        'BANKING', 'PUBLIC-RELATIONS', 'APPAREL', 'INFORMATION-TECHNOLOGY',
#        'INFORMATION-TECHNOLOGY', 'AVIATION', 'ACCOUNTANT',
#        'INFORMATION-TECHNOLOGY', 'FITNESS', 'HEALTHCARE',
#        'INFORMATION-TECHNOLOGY', 'DESIGNER', 'ADVOCATE',
#        'PUBLIC-RELATIONS', 'SALES', 'INFORMATION-TECHNOLOGY', 'BANKING',
#        'BANKING', 'SALES', 'AVIATION', 'BANKING', 'ADVOCATE',
#        'ACCOUNTANT', 'INFORMATION-TECHNOLOGY', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'DESIGNER', 'BUSINESS-DEVELOPMENT',
#        'BUSINESS-DEVELOPMENT', 'PUBLIC-RELATIONS', 'ADVOCATE',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY',
#        'INFORMATION-TECHNOLOGY', 'DESIGNER', 'INFORMATION-TECHNOLOGY',
#        'HR', 'HEALTHCARE', 'PUBLIC-RELATIONS', 'ENGINEERING', 'CHEF',
#        'BUSINESS-DEVELOPMENT', 'ADVOCATE', 'BANKING', 'ENGINEERING',
#        'ADVOCATE', 'CONSTRUCTION', 'AVIATION', 'ACCOUNTANT', 'ACCOUNTANT',
#        'HR', 'FITNESS', 'BUSINESS-DEVELOPMENT', 'HEALTHCARE',
#        'ACCOUNTANT', 'ACCOUNTANT', 'FITNESS', 'AVIATION',
#        'INFORMATION-TECHNOLOGY', 'BANKING', 'BUSINESS-DEVELOPMENT',
#        'CONSTRUCTION', 'HEALTHCARE', 'BANKING', 'AVIATION', 'FINANCE',
#        'CONSTRUCTION', 'PUBLIC-RELATIONS', 'CONSULTANT', 'HEALTHCARE',
#        'ADVOCATE', 'APPAREL', 'INFORMATION-TECHNOLOGY', 'FINANCE',
#        'APPAREL', 'ACCOUNTANT', 'DESIGNER', 'HEALTHCARE', 'ACCOUNTANT',
#        'HEALTHCARE', 'BUSINESS-DEVELOPMENT', 'BANKING', 'CHEF',
#        'ENGINEERING', 'CONSTRUCTION', 'CONSTRUCTION', 'ACCOUNTANT',
#        'CONSTRUCTION', 'ENGINEERING', 'FITNESS', 'DESIGNER',
#        'ENGINEERING', 'AVIATION', 'CHEF', 'ADVOCATE', 'AVIATION',
#        'AVIATION', 'ACCOUNTANT', 'CHEF', 'CHEF', 'FITNESS', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'SALES', 'PUBLIC-RELATIONS', 'TEACHER',
#        'PUBLIC-RELATIONS', 'FINANCE', 'AVIATION', 'HR', 'TEACHER', 'CHEF',
#        'CONSTRUCTION', 'PUBLIC-RELATIONS', 'BANKING', 'SALES', 'BANKING',
#        'HEALTHCARE', 'TEACHER', 'AVIATION', 'TEACHER', 'CHEF',
#        'ENGINEERING', 'ENGINEERING', 'FITNESS', 'CHEF', 'CONSULTANT',
#        'CHEF', 'AVIATION', 'ENGINEERING', 'CHEF', 'ENGINEERING', 'CHEF',
#        'CONSULTANT', 'HEALTHCARE', 'INFORMATION-TECHNOLOGY', 'FITNESS',
#        'FINANCE', 'PUBLIC-RELATIONS', 'CONSTRUCTION', 'BANKING', 'CHEF',
#        'AVIATION', 'CHEF', 'ADVOCATE', 'HR', 'HEALTHCARE', 'FITNESS',
#        'FITNESS', 'HEALTHCARE', 'FITNESS', 'TEACHER', 'CONSTRUCTION',
#        'SALES', 'ENGINEERING', 'HR', 'BANKING', 'PUBLIC-RELATIONS',
#        'ACCOUNTANT', 'TEACHER', 'ENGINEERING', 'BANKING', 'ENGINEERING',
#        'FINANCE', 'CHEF', 'HEALTHCARE', 'HR', 'CHEF', 'ACCOUNTANT',
#        'AVIATION', 'HEALTHCARE', 'CONSTRUCTION', 'ACCOUNTANT',
#        'ACCOUNTANT', 'FINANCE', 'FINANCE', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'HEALTHCARE', 'PUBLIC-RELATIONS', 'HR',
#        'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'HR', 'AGRICULTURE',
#        'DIGITAL-MEDIA', 'BANKING', 'ACCOUNTANT', 'CHEF', 'HR', 'TEACHER',
#        'FINANCE', 'HR', 'CONSTRUCTION', 'BANKING', 'SALES', 'ADVOCATE',
#        'CHEF', 'BUSINESS-DEVELOPMENT', 'HEALTHCARE',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY', 'DIGITAL-MEDIA',
#        'HR', 'HEALTHCARE', 'HR', 'BANKING', 'TEACHER', 'TEACHER',
#        'AVIATION', 'CONSTRUCTION', 'CHEF', 'PUBLIC-RELATIONS',
#        'DIGITAL-MEDIA', 'ENGINEERING', 'ADVOCATE', 'FINANCE',
#        'PUBLIC-RELATIONS', 'FITNESS', 'INFORMATION-TECHNOLOGY',
#        'ENGINEERING', 'DIGITAL-MEDIA', 'ACCOUNTANT', 'DIGITAL-MEDIA',
#        'AVIATION', 'TEACHER', 'BANKING', 'CHEF', 'FINANCE', 'HR',
#        'FINANCE', 'TEACHER', 'HR', 'INFORMATION-TECHNOLOGY',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'ENGINEERING',
#        'ENGINEERING', 'INFORMATION-TECHNOLOGY', 'TEACHER', 'BANKING',
#        'FITNESS', 'ENGINEERING', 'BUSINESS-DEVELOPMENT', 'ENGINEERING',
#        'ACCOUNTANT', 'FINANCE', 'TEACHER', 'PUBLIC-RELATIONS', 'TEACHER',
#        'CHEF', 'BANKING', 'PUBLIC-RELATIONS', 'BUSINESS-DEVELOPMENT',
#        'HEALTHCARE', 'INFORMATION-TECHNOLOGY', 'HR', 'CONSTRUCTION',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'FITNESS',
#        'HEALTHCARE', 'AVIATION', 'PUBLIC-RELATIONS',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'PUBLIC-RELATIONS', 'CHEF',
#        'CHEF', 'TEACHER', 'HEALTHCARE', 'INFORMATION-TECHNOLOGY',
#        'ENGINEERING', 'BUSINESS-DEVELOPMENT', 'CONSTRUCTION',
#        'HEALTHCARE', 'HEALTHCARE', 'BANKING', 'CONSTRUCTION',
#        'ACCOUNTANT', 'HR', 'ACCOUNTANT', 'INFORMATION-TECHNOLOGY',
#        'BUSINESS-DEVELOPMENT', 'DESIGNER', 'ADVOCATE', 'CONSTRUCTION',
#        'HEALTHCARE', 'DESIGNER', 'ACCOUNTANT', 'TEACHER', 'ENGINEERING',
#        'DESIGNER', 'ACCOUNTANT', 'SALES', 'BUSINESS-DEVELOPMENT',
#        'CONSTRUCTION', 'CHEF', 'TEACHER', 'BUSINESS-DEVELOPMENT',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'APPAREL',
#        'TEACHER', 'CHEF', 'ADVOCATE', 'ACCOUNTANT', 'HR', 'HEALTHCARE',
#        'DESIGNER', 'ACCOUNTANT', 'AVIATION', 'INFORMATION-TECHNOLOGY',
#        'PUBLIC-RELATIONS', 'PUBLIC-RELATIONS', 'CHEF', 'HR', 'ACCOUNTANT',
#        'HEALTHCARE', 'CHEF', 'ACCOUNTANT', 'HEALTHCARE', 'CHEF', 'SALES',
#        'HR', 'ACCOUNTANT', 'HEALTHCARE', 'TEACHER', 'HR',
#        'BUSINESS-DEVELOPMENT', 'DESIGNER', 'INFORMATION-TECHNOLOGY',
#        'DIGITAL-MEDIA', 'INFORMATION-TECHNOLOGY', 'SALES', 'CHEF', 'HR',
#        'AVIATION', 'HR', 'CONSTRUCTION', 'FINANCE', 'PUBLIC-RELATIONS',
#        'SALES', 'HR', 'CHEF', 'SALES', 'PUBLIC-RELATIONS',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'ACCOUNTANT', 'CHEF',
#        'ADVOCATE', 'TEACHER', 'ACCOUNTANT', 'BANKING', 'SALES',
#        'INFORMATION-TECHNOLOGY', 'SALES', 'ACCOUNTANT', 'TEACHER',
#        'HEALTHCARE', 'SALES', 'TEACHER', 'HR', 'SALES', 'BANKING',
#        'SALES', 'TEACHER', 'APPAREL', 'INFORMATION-TECHNOLOGY', 'FINANCE',
#        'ADVOCATE', 'AVIATION', 'PUBLIC-RELATIONS', 'ACCOUNTANT',
#        'ACCOUNTANT', 'PUBLIC-RELATIONS', 'CHEF', 'HR', 'HEALTHCARE',
#        'DESIGNER', 'BANKING', 'BANKING', 'AVIATION',
#        'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'HEALTHCARE', 'ENGINEERING',
#        'CHEF', 'ADVOCATE', 'FITNESS', 'PUBLIC-RELATIONS', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'PUBLIC-RELATIONS',
#        'SALES', 'ENGINEERING', 'DIGITAL-MEDIA', 'CONSTRUCTION',
#        'INFORMATION-TECHNOLOGY', 'HEALTHCARE', 'ACCOUNTANT', 'APPAREL',
#        'CONSTRUCTION', 'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'AVIATION',
#        'ENGINEERING', 'ENGINEERING', 'SALES', 'SALES',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY', 'AVIATION',
#        'ENGINEERING', 'APPAREL', 'CONSTRUCTION', 'TEACHER', 'BANKING',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'SALES',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'FINANCE',
#        'BUSINESS-DEVELOPMENT', 'DESIGNER', 'INFORMATION-TECHNOLOGY',
#        'FINANCE', 'SALES', 'ACCOUNTANT', 'ACCOUNTANT', 'ACCOUNTANT',
#        'ACCOUNTANT'], dtype=object)

# %%
print("training Score: {:.2f}".format(RF_Model.score(conuntvectorizer_train, Y_train)))
print("test Score: {:.2f}".format(RF_Model.score(conuntvectorizer_test, Y_test)))
# Out:
# training Score: 0.87
# test Score: 0.61

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
print("model report: %s: \n %s\n" % (RF_Model, metrics.classification_report(Y_test, prediction)))
# Out:
# model report: RandomForestClassifier(max_depth=8, n_estimators=500, random_state=42):
#                          precision    recall  f1-score   support
#
#             ACCOUNTANT       0.46      0.81      0.58        26
#               ADVOCATE       0.88      0.56      0.68        25
#            AGRICULTURE       1.00      0.15      0.27        13
#                APPAREL       0.88      0.47      0.61        15
#                   ARTS       0.00      0.00      0.00        22
#             AUTOMOBILE       0.00      0.00      0.00        10
#               AVIATION       0.71      0.94      0.81        18
#                BANKING       0.67      0.72      0.69        25
#                    BPO       0.00      0.00      0.00         2
#   BUSINESS-DEVELOPMENT       0.54      0.54      0.54        24
#                   CHEF       0.67      0.85      0.75        26
#           CONSTRUCTION       0.54      0.71      0.61        21
#             CONSULTANT       0.60      0.14      0.22        22
#               DESIGNER       0.87      0.68      0.76        19
#          DIGITAL-MEDIA       0.91      0.56      0.69        18
#            ENGINEERING       0.74      0.74      0.74        27
#                FINANCE       0.67      0.39      0.49        31
#                FITNESS       0.67      0.57      0.62        21
#             HEALTHCARE       0.38      0.68      0.49        19
#                     HR       0.70      0.90      0.79        21
# INFORMATION-TECHNOLOGY       0.55      0.93      0.69        28
#       PUBLIC-RELATIONS       0.59      0.89      0.71        18
#                  SALES       0.40      0.38      0.39        26
#                TEACHER       0.51      0.90      0.65        20
#
#               accuracy                           0.61       497
#              macro avg       0.58      0.56      0.53       497
#           weighted avg       0.60      0.61      0.57       497
